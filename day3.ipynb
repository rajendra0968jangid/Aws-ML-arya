# %% [markdown]
# <a href="https://colab.research.google.com/github/rajendra0968jangid/Aws-ML-arya/blob/main/day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rajendra")
# Out:
# rajendra

# %% [markdown]
# **Operators**
# 1. arith -> + , - , * , / , // , % , **
# 2. relational -> > , < , >= , <= , == , !=
# 3. assignment -> += , -=, *= , %=
# 4. logical -> and , or , not
# 5. bitwise -> & , |

# %%
#bitwise opr
num1 = 5
num2 = 3
print(num1 & num2) #
# Out:
# 1

# %%
# logical opr and
num1 = "" # false
num2 = 10 # true
print(num1 and num2)
print(num1 or num2)
# Out:
# 10

# %%
#assignment opr
num1 = 10
num2 = 20
num1 += num2
print(num1)

# -= , *= /= %=
# Out:
# 30

# %%
# relational opr
num1 = 10
num2 = 20
print(num1 > num2) # num1 is greater then num2
# Out:
# False

# %%
num1 = 10
num2 = 20
print(num1 < num2) # num1 is less than num2
# Out:
# True

# %%
num1 = 10
num2 = 10
print(num1 >= num2)

# example ->   <= , == , !=
# Out:
# True

# %%
# arithmatic opr
num1 = 10
num2 = 20
print(num1 + num2) # 30

# example 1
# Out:
# 30

# %%
num1 = 100
num2 = 60
print(num1 - num2)

# example 1
# Out:
# 40

# %%
num1 = 5
num2 = 3
print(num1 * num2)

# example 1
# Out:
# 15

# %%
num1 = 100
num2 = 10
print(num1 / num2)

# example 1
# Out:
# 10.0

# %%
num1 = 100
num2 = 7
print(num1 % num2)

# example 1
# Out:
# 2

# %%
num1 = 100
num2 = 7
print(num1 // num2) # double forward give ouput in integer | Quotient

# example 1
# Out:
# 14

# %%
num1 = 5
num2 = 2
print(num1 ** num2)

# example 1
# Out:
# 25
