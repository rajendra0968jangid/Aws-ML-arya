# %%
print("hello")
# Out:
# hello

# %% [markdown]
# **What is Pandas?**

# %%
# !pip install pandas

# %% [markdown]
# **Pandas is a Python library used for:**
#
# 1. Reading data
# 2. Cleaning data
# 3. Analyzing data
# 4. Manipulating data

# %% [markdown]
# **create DataFrame**
# 1. DataFrame for list 1d (pd series)
# 2. list -> indexing name (pd dataframe)
# 3. DataFrame for dict

# %% [markdown]
# **Help and Suggestion**
# 1. help(pd.Series)
# 2. pd.Series??

# %% [markdown]
# **Save and Load data from CSV,json,excel**
# 1. url = "https://raw.githubusercontent.com/rajendra0968jangid/machine_learning_demo/main/placement.csv"
# 2. csv import -> pd.read_csv("filename")
# 3. csv export -> df.to_csv('filename')
# 4. json import -> pd.read_json('filename')
# 5. json export -> df.to_json('filename')
# 6. excel import -> pd.read_excel('filename', sheet_name='Sheet1')
# 7. excel export -> df.to_excel('filename', index=False, sheet_name='Sheet1')

# %% [markdown]
# **Basic Dataframe Understanding**
# 1. head()
# 2. tail()
# 3. shape
# 4. info()
# 5. rename
# 6. describe()-> count,mean,std,min,max
