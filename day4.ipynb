# %% [markdown]
# <a href="https://colab.research.google.com/github/rajendra0968jangid/Aws-ML-arya/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("day 4")
# Out:
# day 4

# %%
# list method append
l = [10,20,30]
l.append(40)
l
# Out:
# [10, 20, 30, 40]

# %%
# list method insert
l = [10,20,30]
l.insert(1,100)
l
# Out:
# [10, 100, 20, 30]

# %%
#length
l = [10,20,30]
print(len(l))
# Out:
# 3

# %%
# list element access
l = [10,20,30]
print(l[0])
# Out:
# 10

# %%
# for
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# for in list
for i in [10,20,30]:
  print(i)
# Out:
# 10
# 20
# 30

# %%
l = [10,20,30]
for i in l:
  print(i)
# Out:
# 10
# 20
# 30

# %%
l = [10,20,30]
len(l)
# Out:
# 3

# %%
for i in range(3):
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(len(l)):
  print(i)
# Out:
# 0
# 1
# 2

# %%
for i in range(len(l)):
  print(l[i])
# Out:
# 10
# 20
# 30

# %%
d = {"users":['nikhil','raj']}
d['users'][0]
# Out:
# 'nikhil'

# %%
for i in range(2):
  print(i)
# Out:
# 0
# 1

# %%
for i in range(2):
  print(d['users'])
# Out:
# ['nikhil', 'raj']
# ['nikhil', 'raj']

# %%
for i in range(2):
  print(d['users'][i])
# Out:
# nikhil
# raj

# %%
for i in range(len(d['users'])):
  print(d['users'][i])
# Out:
# nikhil
# raj

# %%
# latest approch
for i in d['users']:
  print(i)
# Out:
# nikhil
# raj

# %%
def hello():
  print("hello function")
hello()
# Out:
# hello function

# %%
def name(a):
  print(a)
name("rajendra")
# Out:
# rajendra

# %%
def name(a,b):
  print(a,b)
name("rajendra","mishra")
# Out:
# rajendra mishra

# %%
def name(*a):
  print(a)

name('nikhil','raj')
name('a','b','c','d','e')
name('hello')
# Out:
# ('nikhil', 'raj')
# ('a', 'b', 'c', 'd', 'e')
# ('hello',)

# %%
def name(*a):
  for i in a:
    print(i)

name('nikhil','raj')
name('a','b','c','d','e')
name('hello')
# Out:
# nikhil
# raj
# a
# b
# c
# d
# e
# hello

# %%
def atm(a):
  return a

pocket = atm(200)
pocket
# Out:
# 200

# %%
def atm(a,b):
  print( a + b )
pocket = atm(200,500)
print(pocket)
# Out:
# 700
# None

# %%
def atm(a,b):
  print( a + b )
  return a+b
pocket = atm(200,500)
print(pocket)
# Out:
# 700
# 700
